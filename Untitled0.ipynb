# %%
# !pip install --quiet tensorflow-federated
# Out:
#      |████████████████████████████████| 583kB 5.4MB/s
#      |████████████████████████████████| 174kB 9.6MB/s
#      |████████████████████████████████| 706kB 10.0MB/s
#      |████████████████████████████████| 194kB 11.1MB/s
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.

# %%
import tensorflow_federated as tff

import inspect

for name, obj in inspect.getmembers(tff.simulation):
    if inspect.isclass(obj):
        print (obj)

# <class 'tensorflow_federated.python.simulation.csv_manager.CSVMetricsManager'>
# <class 'tensorflow_federated.python.simulation.checkpoint_manager.FileCheckpointManager'>
# <class 'tensorflow_federated.python.simulation.metrics_manager.MetricsManager'>
# <class 'tensorflow_federated.python.simulation.tensorboard_manager.TensorBoardManager'>
# Out:
# <class 'tensorflow_federated.python.simulation.csv_manager.CSVMetricsManager'>
# <class 'tensorflow_federated.python.simulation.client_data.ClientData'>
# <class 'tensorflow_federated.python.simulation.checkpoint_manager.FileCheckpointManager'>
# <class 'tensorflow_federated.python.simulation.file_per_user_client_data.FilePerUserClientData'>
# <class 'tensorflow_federated.python.simulation.from_tensor_slices_client_data.FromTensorSlicesClientData'>
# <class 'tensorflow_federated.python.simulation.hdf5_client_data.HDF5ClientData'>
# <class 'tensorflow_federated.python.simulation.metrics_manager.MetricsManager'>
# <class 'tensorflow_federated.python.simulation.tensorboard_manager.TensorBoardManager'>
# <class 'tensorflow_federated.python.simulation.transforming_client_data.TransformingClientData'>
